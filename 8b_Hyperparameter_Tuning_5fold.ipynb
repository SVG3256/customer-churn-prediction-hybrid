# %%
import pandas as pd
import numpy as np
import pickle
import json
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, classification_report, make_scorer
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open('models/baseline_models.pkl', 'rb') as f:
    models_dict = pickle.load(f)

best_model_name = models_dict['best_model_name']
feature_cols = models_dict['feature_cols']

print(f"\nBest model based on previous analysis: {best_model_name}")
print(f"Features: {len(feature_cols)}")

with open('outputs/performance_summary.json', 'r') as f:
    baseline_performance = json.load(f)

print(f"\nBaseline performance:")
print(f"  OOS AUC: {baseline_performance['oos_auc']:.4f}")
print(f"  OOT AUC: {baseline_performance['oot_auc']:.4f}")
# Out:
# Best model based on previous analysis: XGBoost
# Features: 10
#
# Baseline performance:
#   OOS AUC: 0.7573
#   OOT AUC: 0.6860

# %%
df = pd.read_csv('data/cfpb_complaints_target_creation.csv')
df['Date received'] = pd.to_datetime(df['Date received'])
df.head()
# Out:
#   Date received                                            Product  \
# 0    2025-01-20  Credit reporting or other personal consumer re...
# 1    2024-07-03  Credit reporting or other personal consumer re...
# 2    2025-09-14                              Vehicle loan or lease
# 3    2025-05-01  Credit reporting or other personal consumer re...
# 4    2025-12-08  Credit reporting or other personal consumer re...
#
#         Sub-product                                 Issue  \
# 0  Credit reporting  Incorrect information on your report
# 1  Credit reporting           Improper use of your report
# 2              Loan  Incorrect information on your report
# 3  Credit reporting  Incorrect information on your report
# 4  Credit reporting  Incorrect information on your report
#
#                                        Sub-issue  \
# 0            Information belongs to someone else
# 1  Reporting company used your report improperly
# 2            Information belongs to someone else
# 3            Information belongs to someone else
# 4                  Account information incorrect
#
#                                   Company State ZIP code Submitted via  \
# 0  TRANSUNION INTERMEDIATE HOLDINGS, INC.    CA    92345           Web
# 1     Experian Information Solutions Inc.    FL    32824           Web
# 2            SANTANDER HOLDINGS USA, INC.    PA    19143           Web
# 3  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    76105           Web
# 4        Kubota North America Corporation    MS    391XX           Web
#
#       Company response to consumer  ... churn_intent  loyalty_score  \
# 0  Closed with non-monetary relief  ...          0.4            0.0
# 1  Closed with non-monetary relief  ...          0.0            0.0
# 2          Closed with explanation  ...          0.4            0.0
# 3  Closed with non-monetary relief  ...          0.0            0.0
# 4          Closed with explanation  ...          0.0            0.0
#
#   text_length word_count  dominant_topic  \
# 0         662        119              23
# 1         370         68               5
# 2         830        140              27
# 3         127         18              39
# 4         107         17               3
#
#                           topic_granular            topic_category  \
# 0       T23_credit-report_deleted-credit    Identity Theft / Fraud
# 1       T05_credit-report_credit-reports   Credit Reporting Errors
# 2           T27_credit-reporting_federal   Credit Reporting Errors
# 3  T39_credit-report_inaccurate-accounts   Credit Reporting Errors
# 4                       T03_account_bank  Account / Payment Issues
#
#    churn_risk_tier  resolution_tier  year_month
# 0         Moderate                1     2025-01
# 1          Minimal                1     2024-07
# 2         Moderate                0     2025-09
# 3          Minimal                1     2025-05
# 4          Minimal                0     2025-12
#
# [5 rows x 29 columns]

# %%
train_mask = (df['Date received'] >= '2024-02-01') & (df['Date received'] < '2025-08-01')
oot_mask = (df['Date received'] >= '2025-08-01') & (df['Date received'] < '2025-12-01')

train_data = df[train_mask].copy()
oot_data = df[oot_mask].copy()

# Features and target
X_train = train_data[feature_cols].fillna(0)
y_train = train_data['resolution_tier']

X_oot = oot_data[feature_cols].fillna(0)
y_oot = oot_data['resolution_tier']

print(f"\nTraining set: {len(X_train):,}")
print(f"OOT set: {len(X_oot):,}")
# Out:
# Training set: 787,500
# OOT set: 177,726

# %%
df
# Out:
#         Date received                                            Product  \
# 0          2025-01-20  Credit reporting or other personal consumer re...
# 1          2024-07-03  Credit reporting or other personal consumer re...
# 2          2025-09-14                              Vehicle loan or lease
# 3          2025-05-01  Credit reporting or other personal consumer re...
# 4          2025-12-08  Credit reporting or other personal consumer re...
# ...               ...                                                ...
# 1399213    2024-04-20  Credit reporting or other personal consumer re...
# 1399214    2023-12-18  Credit reporting or other personal consumer re...
# 1399215    2024-03-06  Credit reporting or other personal consumer re...
# 1399216    2024-11-01  Credit reporting or other personal consumer re...
# 1399217    2025-09-08  Credit reporting or other personal consumer re...
#
#               Sub-product                                              Issue  \
# 0        Credit reporting               Incorrect information on your report
# 1        Credit reporting                        Improper use of your report
# 2                    Loan               Incorrect information on your report
# 3        Credit reporting               Incorrect information on your report
# 4        Credit reporting               Incorrect information on your report
# ...                   ...                                                ...
# 1399213  Credit reporting               Incorrect information on your report
# 1399214  Credit reporting                        Improper use of your report
# 1399215  Credit reporting  Problem with a company's investigation into an...
# 1399216  Credit reporting                        Improper use of your report
# 1399217  Credit reporting               Incorrect information on your report
#
#                                              Sub-issue  \
# 0                  Information belongs to someone else
# 1        Reporting company used your report improperly
# 2                  Information belongs to someone else
# 3                  Information belongs to someone else
# 4                        Account information incorrect
# ...                                                ...
# 1399213            Information belongs to someone else
# 1399214  Reporting company used your report improperly
# 1399215           Investigation took more than 30 days
# 1399216  Reporting company used your report improperly
# 1399217            Information belongs to someone else
#
#                                         Company State ZIP code Submitted via  \
# 0        TRANSUNION INTERMEDIATE HOLDINGS, INC.    CA    92345           Web
# 1           Experian Information Solutions Inc.    FL    32824           Web
# 2                  SANTANDER HOLDINGS USA, INC.    PA    19143           Web
# 3        TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    76105           Web
# 4              Kubota North America Corporation    MS    391XX           Web
# ...                                         ...   ...      ...           ...
# 1399213  TRANSUNION INTERMEDIATE HOLDINGS, INC.    FL    33312           Web
# 1399214  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    78640           Web
# 1399215     Experian Information Solutions Inc.    TX    75217           Web
# 1399216     Experian Information Solutions Inc.    MI    48124           Web
# 1399217  TRANSUNION INTERMEDIATE HOLDINGS, INC.    AZ    85364           Web
#
#             Company response to consumer  ... churn_intent  loyalty_score  \
# 0        Closed with non-monetary relief  ...          0.4            0.0
# 1        Closed with non-monetary relief  ...          0.0            0.0
# 2                Closed with explanation  ...          0.4            0.0
# 3        Closed with non-monetary relief  ...          0.0            0.0
# 4                Closed with explanation  ...          0.0            0.0
# ...                                  ...  ...          ...            ...
# 1399213  Closed with non-monetary relief  ...          0.0            0.0
# 1399214  Closed with non-monetary relief  ...          0.0            0.4
# 1399215          Closed with explanation  ...          0.0            0.0
# 1399216          Closed with explanation  ...          0.0            0.0
# 1399217  Closed with non-monetary relief  ...          0.0            0.0
#
#         text_length word_count  dominant_topic  \
# 0               662        119              23
# 1               370         68               5
# 2               830        140              27
# 3               127         18              39
# 4               107         17               3
# ...             ...        ...             ...
# 1399213         184         34              33
# 1399214        1231        223              12
# 1399215         710        117              21
# 1399216        4169        729              18
# 1399217         403         69              47
#
#                                   topic_granular            topic_category  \
# 0               T23_credit-report_deleted-credit    Identity Theft / Fraud
# 1               T05_credit-report_credit-reports   Credit Reporting Errors
# 2                   T27_credit-reporting_federal   Credit Reporting Errors
# 3          T39_credit-report_inaccurate-accounts   Credit Reporting Errors
# 4                               T03_account_bank  Account / Payment Issues
# ...                                          ...                       ...
# 1399213         T33_credit-report_credit-bureaus    Identity Theft / Fraud
# 1399214  T12_reporting-agency_consumer-reporting   Credit Reporting Errors
# 1399215  T21_credit-reporting_efficiency-banking   Credit Reporting Errors
# 1399216                      T18_debt_collection           Debt Collection
# 1399217                         T47_loan_payment  Account / Payment Issues
#
#          churn_risk_tier  resolution_tier  year_month
# 0               Moderate                1     2025-01
# 1                Minimal                1     2024-07
# 2               Moderate                0     2025-09
# 3                Minimal                1     2025-05
# 4                Minimal                0     2025-12
# ...                  ...              ...         ...
# 1399213          Minimal                1     2024-04
# 1399214          Minimal                1     2023-12
# 1399215          Minimal                0     2024-03
# 1399216          Minimal                0     2024-11
# 1399217          Minimal                1     2025-09
#
# [1399218 rows x 29 columns]

# %%
from xgboost import XGBClassifier
    
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [6, 8, 10],
    'learning_rate': [0.05, 0.1],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'gamma': [0, 0.1]
}
    
base_model = XGBClassifier(
    random_state=42,
    n_jobs=-1,
    eval_metric='mlogloss',
    verbosity=0
)

# %%
print(f"\nModel: {best_model_name}")
print(f"Parameters to tune: {len(param_grid)}")
print("\nParameter grid:")
for param, values in param_grid.items():
    print(f"  {param}: {values}")

total_combinations = np.prod([len(v) for v in param_grid.values()])
print(f"\nTotal combinations: {total_combinations:,}")
# Out:
# Model: XGBoost
# Parameters to tune: 6
#
# Parameter grid:
#   n_estimators: [100, 200]
#   max_depth: [6, 8, 10]
#   learning_rate: [0.05, 0.1]
#   subsample: [0.8, 1.0]
#   colsample_bytree: [0.8, 1.0]
#   gamma: [0, 0.1]
#
# Total combinations: 96

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.metrics import make_scorer

def multiclass_auc_scorer(y_true, y_pred_proba, sample_weight=None, **kwargs):
    y_true_bin = label_binarize(y_true, classes=[0, 1, 2])
    return roc_auc_score(y_true_bin, y_pred_proba, multi_class='ovo', average='macro', sample_weight=sample_weight)

auc_scorer = make_scorer(multiclass_auc_scorer, response_method='predict_proba')

# Grid search with 5-fold CV
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid,
    cv=5,
    scoring=auc_scorer,
    n_jobs=-1,
    verbose=2,
    return_train_score=True
)

# %%
print("\n" + "="*80)
print("RUNNING GRID SEARCH")
print("="*80)

import time

start_time = time.time()
print(f"\nStarting grid search with 3-fold CV...")
class_counts = y_train.value_counts()
total = len(y_train)
weights = {cls: total / (len(class_counts) * count) for cls, count in class_counts.items()}
sample_weights = y_train.map(weights)
grid_search.fit(X_train, y_train, sample_weight=sample_weights)

end_time = time.time()
duration = end_time - start_time

print("\nGrid search complete")
print(f"Grid search took {duration:.2f} seconds.")
# Out:
# ================================================================================
# RUNNING GRID SEARCH
# ================================================================================
#
# Starting grid search with 3-fold CV...
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
#
# Grid search complete
# Grid search took 2285.94 seconds.

# %%
print("\n" + "="*80)
print("GRID SEARCH RESULTS")
print("="*80)

print("\nBest parameters found:")
for param, value in grid_search.best_params_.items():
    print(f"  {param}: {value}")

print(f"\nBest CV score: {grid_search.best_score_:.4f}")
print(f"Baseline OOS AUC: {baseline_performance['oos_auc']:.4f}")
print(f"Improvement: {(grid_search.best_score_ - baseline_performance['oos_auc']):.4f}")
# Out:
# ================================================================================
# GRID SEARCH RESULTS
# ================================================================================
#
# Best parameters found:
#   colsample_bytree: 0.8
#   gamma: 0.1
#   learning_rate: 0.1
#   max_depth: 6
#   n_estimators: 200
#   subsample: 0.8
#
# Best CV score: 0.8339
# Baseline OOS AUC: 0.7573
# Improvement: 0.0765

# %%
results_df = pd.DataFrame(grid_search.cv_results_)
results_df = results_df.sort_values('rank_test_score')
results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 38      83.180689      4.614167         1.246434        0.266402
# 14      81.941927      0.348863         1.623325        0.012613
# 86      86.665458      8.562290         1.641751        0.386152
# 62      82.213457      3.212938         1.051642        0.077444
# 15      62.159528      0.262186         1.601846        0.053564
# ..            ...           ...              ...             ...
# 71     108.283096      7.477505        13.221955        1.339107
# 95      60.033873      1.029835         4.505270        0.814017
# 46     133.971513      3.506947        10.345405        1.586948
# 70     128.969016      7.019177        10.048412        1.461866
# 94      79.676186      3.024978         3.929481        0.403839
#
#     param_colsample_bytree  param_gamma  param_learning_rate  param_max_depth  \
# 38                     0.8          0.1                  0.1                6
# 14                     0.8          0.0                  0.1                6
# 86                     1.0          0.1                  0.1                6
# 62                     1.0          0.0                  0.1                6
# 15                     0.8          0.0                  0.1                6
# ..                     ...          ...                  ...              ...
# 71                     1.0          0.0                  0.1               10
# 95                     1.0          0.1                  0.1               10
# 46                     0.8          0.1                  0.1               10
# 70                     1.0          0.0                  0.1               10
# 94                     1.0          0.1                  0.1               10
#
#     param_n_estimators  param_subsample  ... mean_test_score  std_test_score  \
# 38                 200              0.8  ...        0.833865        0.001265
# 14                 200              0.8  ...        0.833822        0.001215
# 86                 200              0.8  ...        0.833689        0.000928
# 62                 200              0.8  ...        0.833665        0.001128
# 15                 200              1.0  ...        0.833626        0.001032
# ..                 ...              ...  ...             ...             ...
# 71                 200              1.0  ...        0.818808        0.002092
# 95                 200              1.0  ...        0.818734        0.002094
# 46                 200              0.8  ...        0.818708        0.002062
# 70                 200              0.8  ...        0.818191        0.002236
# 94                 200              0.8  ...        0.818049        0.002059
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 38                1            0.853437            0.853573
# 14                2            0.853541            0.853636
# 86                3            0.854139            0.854133
# 62                4            0.853926            0.854092
# 15                5            0.851309            0.851769
# ..              ...                 ...                 ...
# 71               92            0.899762            0.899237
# 95               93            0.899798            0.898508
# 46               94            0.902865            0.902304
# 70               95            0.903087            0.902980
# 94               96            0.903348            0.903186
#
#     split2_train_score  split3_train_score  split4_train_score  \
# 38            0.853205            0.853781            0.853070
# 14            0.853103            0.853820            0.852932
# 86            0.853759            0.854118            0.853468
# 62            0.853528            0.854096            0.853575
# 15            0.851461            0.852556            0.851458
# ..                 ...                 ...                 ...
# 71            0.898853            0.898935            0.899825
# 95            0.898296            0.899960            0.899641
# 46            0.901578            0.902311            0.902503
# 70            0.901440            0.902928            0.902590
# 94            0.901944            0.903546            0.902406
#
#     mean_train_score  std_train_score
# 38          0.853413         0.000254
# 14          0.853407         0.000334
# 86          0.853923         0.000269
# 62          0.853843         0.000246
# 15          0.851711         0.000449
# ..               ...              ...
# 71          0.899323         0.000406
# 95          0.899241         0.000696
# 46          0.902312         0.000420
# 70          0.902605         0.000606
# 94          0.902886         0.000610
#
# [96 rows x 26 columns]

# %%
print("\n" + "-"*80)
print("TOP 10 CONFIGURATIONS")
print("-"*80)

top_10 = results_df.head(10)[['params', 'mean_test_score', 'std_test_score', 'rank_test_score']]
for idx, row in top_10.iterrows():
    print(f"\nRank {int(row['rank_test_score'])}:")
    print(f"  Score: {row['mean_test_score']:.4f} (+/- {row['std_test_score']:.4f})")
    print(f"  Params: {row['params']}")
# Out:
# --------------------------------------------------------------------------------
# TOP 10 CONFIGURATIONS
# --------------------------------------------------------------------------------
#
# Rank 1:
#   Score: 0.8339 (+/- 0.0013)
#   Params: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#
# Rank 2:
#   Score: 0.8338 (+/- 0.0012)
#   Params: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#
# Rank 3:
#   Score: 0.8337 (+/- 0.0009)
#   Params: {'colsample_bytree': 1.0, 'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#
# Rank 4:
#   Score: 0.8337 (+/- 0.0011)
#   Params: {'colsample_bytree': 1.0, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
#
# Rank 5:
#   Score: 0.8336 (+/- 0.0010)
#   Params: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 1.0}
#
# Rank 6:
#   Score: 0.8336 (+/- 0.0009)
#   Params: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'subsample': 1.0}
#
# Rank 7:
#   Score: 0.8335 (+/- 0.0011)
#   Params: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 200, 'subsample': 0.8}
#
# Rank 8:
#   Score: 0.8335 (+/- 0.0011)
#   Params: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 200, 'subsample': 0.8}
#
# Rank 9:
#   Score: 0.8335 (+/- 0.0012)
#   Params: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100, 'subsample': 0.8}
#
# Rank 10:
#   Score: 0.8334 (+/- 0.0011)
#   Params: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100, 'subsample': 0.8}

# %%
results_df.to_csv('outputs/grid_search_results_5fold.csv', index=False)

# %%
grid_search.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=0.1,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
optimized_model = grid_search.best_estimator_

# OOT predictions
y_pred_oot = optimized_model.predict(X_oot)
y_proba_oot = optimized_model.predict_proba(X_oot)

# %%
print("\n" + "="*80)
print("EVALUATING OPTIMIZED MODEL")
print("="*80)

print("\n" + "-"*80)
print("OOT PERFORMANCE (Optimized)")
print("-"*80)
print("\nClassification Report:")
print(classification_report(y_oot, y_pred_oot,
                          target_names=['Tier 0', 'Tier 1', 'Tier 2'],
                          digits=4))

# Multi-class AUC
y_oot_bin = label_binarize(y_oot, classes=[0, 1, 2])
auc_ovo_oot = roc_auc_score(y_oot_bin, y_proba_oot,
                            multi_class='ovo', average='macro')

print(f"Multi-class AUC (one-vs-one): {auc_ovo_oot:.4f}")
# Out:
# ================================================================================
# EVALUATING OPTIMIZED MODEL
# ================================================================================
#
# --------------------------------------------------------------------------------
# OOT PERFORMANCE (Optimized)
# --------------------------------------------------------------------------------
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Tier 0     0.7034    0.2576    0.3771    119787
#       Tier 1     0.3724    0.7149    0.4897     55199
#       Tier 2     0.0903    0.9197    0.1645      2740
#
#     accuracy                         0.4099    177726
#    macro avg     0.3887    0.6307    0.3438    177726
# weighted avg     0.5912    0.4099    0.4088    177726
#
# Multi-class AUC (one-vs-one): 0.6775

# %%
print(f"Baseline OOT AUC: {baseline_performance['oot_auc']:.4f}")
print(f"Optimized OOT AUC: {auc_ovo_oot:.4f}")
print(f"Improvement: {(auc_ovo_oot - baseline_performance['oot_auc']):.4f} ({(auc_ovo_oot - baseline_performance['oot_auc'])/baseline_performance['oot_auc']*100:.1f}%)")

if auc_ovo_oot > baseline_performance['oot_auc']:
    print("Optimization improved performance")
else:
    print("No improvement observed - baseline may be optimal")
# Out:
# Baseline OOT AUC: 0.6860
# Optimized OOT AUC: 0.6775
# Improvement: -0.0085 (-1.2%)
# No improvement observed - baseline may be optimal

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix

cm_optimized = confusion_matrix(y_oot, y_pred_oot)

fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(cm_optimized, annot=True, fmt='d', cmap='Greens', ax=ax,
            xticklabels=['Tier 0', 'Tier 1', 'Tier 2'],
            yticklabels=['Tier 0', 'Tier 1', 'Tier 2'])
ax.set_title(f'{best_model_name} (Optimized) - Confusion Matrix (OOT)', 
             fontsize=12, fontweight='bold')
ax.set_ylabel('Actual')
ax.set_xlabel('Predicted')
plt.tight_layout()
plt.savefig('outputs/optimized_confusion_matrix_5fold.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
print("\n" + "="*80)
print("FEATURE IMPORTANCE (Optimized)")
print("="*80)

feature_importance = pd.DataFrame({
    'feature': feature_cols,
    'importance': optimized_model.feature_importances_
}).sort_values('importance', ascending=False)
    
print("\n")
print(feature_importance.to_string(index=False))
    
fig, ax = plt.subplots(figsize=(10, 6))
feature_importance.plot(x='feature', y='importance', kind='barh', ax=ax, color='forestgreen')
ax.set_title(f'{best_model_name} (Optimized) - Feature Importance', 
             fontsize=12, fontweight='bold')
ax.set_xlabel('Importance')
ax.set_ylabel('Feature')
plt.tight_layout()
plt.savefig('outputs/optimized_feature_importance_5fold.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ================================================================================
# FEATURE IMPORTANCE (Optimized)
# ================================================================================
#
#
#            feature  importance
#     dominant_topic    0.518638
#      loyalty_score    0.176257
#       churn_intent    0.097508
#      sentiment_neu    0.035396
#      sentiment_pos    0.031820
#      urgency_score    0.030279
#         word_count    0.029376
#      sentiment_neg    0.029300
#        text_length    0.028352
# sentiment_compound    0.023074

# %%
optimized_dict = {
    'model': optimized_model,
    'model_name': best_model_name,
    'best_params': grid_search.best_params_,
    'cv_score': grid_search.best_score_,
    'oot_auc': auc_ovo_oot,
    'feature_cols': feature_cols
}

with open('models/optimized_model.pkl', 'wb') as f:
    pickle.dump(optimized_dict, f)

print("\nOptimized model saved to models/optimized_model.pkl")

performance_comparison = pd.DataFrame({
    'Model': ['Baseline', 'Optimized'],
    'OOS_AUC': [baseline_performance['oos_auc'], grid_search.best_score_],
    'OOT_AUC': [baseline_performance['oot_auc'], auc_ovo_oot]
})

performance_comparison.to_csv('outputs/optimization_comparison_5fold.csv', index=False)
print("Performance comparison saved to outputs/optimization_comparison_5fold.csv")
# Out:
# Optimized model saved to models/optimized_model.pkl
# Performance comparison saved to outputs/optimization_comparison_5fold.csv

# %%
optimized_performance = {
    'model': best_model_name,
    'best_params': grid_search.best_params_,
    'cv_score': float(grid_search.best_score_),
    'oot_auc': float(auc_ovo_oot),
    'improvement_over_baseline': float(auc_ovo_oot - baseline_performance['oot_auc'])
}

with open('outputs/optimized_performance.json', 'w') as f:
    json.dump(optimized_performance, f, indent=2)

print("Optimized performance saved to outputs/optimized_performance_5fold.json")
# Out:
# Optimized performance saved to outputs/optimized_performance_5fold.json
